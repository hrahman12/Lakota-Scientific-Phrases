# %% [markdown]
# All rights go to
# : https://github.com/OJB-Quantum/Navaho-Linguistics

# %%
# Install a pip package in the current Jupyter kernel

import sys
# !{sys.executable} -m pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %%
pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2023.7.22)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
pip install pyshorteners
# Out:
# Collecting pyshorteners
#   Downloading pyshorteners-1.0.1.tar.gz (10.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyshorteners) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (2023.7.22)
# Building wheels for collected packages: pyshorteners
#   Building wheel for pyshorteners (setup.py) ... done
#   Created wheel for pyshorteners: filename=pyshorteners-1.0.1-py3-none-any.whl size=17481 sha256=dbd0779f296da66577c8f4e4ce6271ba60f53b090906b53cdefd0ab1ee84342a
#   Stored in directory: /root/.cache/pip/wheels/d5/ff/b3/16d8906f92ab0b042f76a4696fcea11d291d79a2b3a3de1e78
# Successfully built pyshorteners
# Installing collected packages: pyshorteners
# Successfully installed pyshorteners-1.0.1

# %%
# Wiki version with 2 summaries and URLs tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

# For the keywords below, don't forget to insert commas
keywords = [
    "X",
    "Invention of X"
    "importance of X",
    "ideal behavior of X",
    "ideal vs. realistic behavior of X",
    "significance of X",
    "applications of X",
    "physical significance of X",
    "geometry used in X",
    "typical characteristics of X",
    "with and without X",
    "what does X represent?",
    "what is the concept of X?",
    "taxonomy of X",
    "table of X",
    "list of X"
    "X and people"
    "X table",
    "the analog of X",
    "physical meaning of X",
    "X symbolism",
    "symbolism of X",
    "iconographic meaning of X",
    "why is X important?",
    "generic model of a X",
    "generic model representation of X",
    "schematic representation of X",
    "X is related to?",
    "X conversions"
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:2]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Lakota
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# | Keyword                                     | Summary 1                                                                                                                                                                                                           | URL 1                        | Summary 2                                                                                                                                                                                                                           | URL 2                        |
# |:--------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# | Lakota symbolism                            | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ) is a Siouan language spoken by the Sioux people . Lakota is also known as Lakhota, Teton or Teton Sioux .                                                                        | https://tinyurl.com/2n63xvh6 | Lakota spirituality is the traditional Native American religion of the <span class="searchmatch">Lakota</span> people . It is practiced primarily in Lakota reservations .                                                          | https://tinyurl.com/ykly49ax |
# | symbolism of Lakota                         | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ), also referred to as Lakhota, Teton or Teton Sioux, is a Siouan language .                                                                                                       | https://tinyurl.com/2n63xvh6 | Lakota spirituality is the traditional Native American religion of the Lakota people . It is practiced primarily in the <span class="searchmatch">Lakota  reservations .                                                            | https://tinyurl.com/ykly49ax |
# | iconographic meaning of Lakota              | Another myth mentions that the bottom half <span class="searchmatch">of </span> Orion, the Constellation <span> of the Hand, represented the arm of a chief that was ripped . is its tail .                         | https://tinyurl.com/yyf224af | AAVSO: The Myths <span class="searchmatch">of</span> Ursa Major The Origin The Origin of the Greek Constellations (paywalled) Warburg Institute <span> Institute (ca 160)                                                           | https://tinyurl.com/ybvjcqme |
# | why is Lakota important?                    | The Sioux or Oceti Sakowin (/suː/ SOO; Dakota/) are groups of Native American tribes and First Nations peoples . They are known as Lakota or Očhéthi Šakówiŋ .                                                      | https://tinyurl.com/ya6aqvy3 | Dakota, Dakota, became an important source to the Lakota for lodge poles, plant resources and small game . They are considered sacred to the <span class="searchmatch">Lakota</span> culture .                                      | https://tinyurl.com/y8yqkwlb |
# | generic model of a Lakota                   | The school is within two hours of the Cheyenne River Indian Reservation, the Lower Lakota Reservation . independent of the diocese . It is within 2 hours of three reservations within the Diocese of Lakota .      | https://tinyurl.com/ykfw3ba6 | In 1874, the U.S. government encroaches on the lands <span class="searchmatch">of</span> the Lakota people . Mattotaupa is one of the most successful pictures produced by the DEFA film studio .                                   | https://tinyurl.com/yketo73w |
# | generic model representation of Lakota      | is the <span class="searchmatch">Lakota term for non-Indian white person, but it also means &quot;the one who takes the best meat for himself . Clarke, Donald. is the author of "All kinds of things"              | https://tinyurl.com/9srcblt  | The specific name is derived from <span class="searchmatch">Lakota <span> mah-koo yah-nah-pin, &quot;breast necklace&quot ;, a reference to the pairs <span of apatosaurus (A. yahnahpin) species .                                 | https://tinyurl.com/z7kpjbh  |
# | schematic representation of Lakota          | Buffalo County, South Dakota, is home <span class="searchmatch">of the Crow Creek Indian Reservation, and Oglala <span>Lakota</span> County . Buffalo County is home to the Pine Ridge and Crow Creek Reservation . | https://tinyurl.com/hnl32fz  | The dance was part of a religion founded by Wovoka that told the return of the Messiah to relieve the suffering <span class="searchmatch"> of Native Americans .                                                                    | https://tinyurl.com/h5sw32u  |
# | Lakota is related to?                       | The Lakota are a Native American people . Also known as the Teton Sioux (from Thítȟuŋwaŋ), they are one of the largest tribes in the world .                                                                        | https://tinyurl.com/sryvcns  | Look up <span class="searchmatch">lakota" in Wiktionary, the free dictionary . Use the search engine to help people understand the meaning of this article .                                                                        | https://tinyurl.com/yvvgqrhd |
# | Lakota conversions                          | Lakota spirituality is the traditional Native American religion of the <span class="searchmatch">Lakota</span> people . It is practiced primarily in Lakota reservations .                                          | https://tinyurl.com/ykly49ax | Wakan Tanka is a Supreme Being or god known more specifically as Wakan tanka in <span class="searchmatch">Lakota <span> and Gitche Manitou in Algonquian, and by other, specific, specific force force .                            | https://tinyurl.com/yufylnpe |

# %%
# Wiki version with 1 summary and URL each tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

# For the keywords below, don't forget to insert commas
keywords = [
    "X",
    "Invention of X"
    "importance of X",
    "ideal behavior of X",
    "ideal vs. realistic behavior of X",
    "significance of X",
    "applications of X",
    "physical significance of X",
    "geometry used in X",
    "typical characteristics of X",
    "with and without X",
    "what does X represent?",
    "what is the concept of X?",
    "taxonomy of X",
    "table of X",
    "list of X"
    "X and people"
    "X table",
    "the analog of X",
    "physical meaning of X",
    "X symbolism",
    "symbolism of X",
    "iconographic meaning of X",
    "why is X important?",
    "generic model of a X",
    "generic model representation of X",
    "schematic representation of X",
    "X is related to?",
    "X conversions"
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:1]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Lakota
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# | Keyword                                     | Summary 1                                                                                                                                                                                                                                               | URL 1                        |
# |:--------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|
# | Lakota                                      | Look up <span class="searchmatch">lakota" in Wiktionary, the free dictionary . The name may refer to the Lakota people, a confederation of seven related Native American tribes .                                                                       | https://tinyurl.com/yvvgqrhd |
# | ideal behavior of Lakota                    | Akta <span class="searchmatch">Lakota</span> Museum and Cultural Center. Archived from the original on 10 August 2014 .                                                                                                                                 | https://tinyurl.com/nn6qsvn  |
# | ideal vs. realistic behavior of Lakota      | The Great Sioux War <span class="searchmatch">of</span> 1876 was conducted by the Lakota under Sitting Bull and Crazy Horse . The Lakota were finally surrounded at the Battle of Bear Paw and surrendered .                                            | https://tinyurl.com/ya6ulhsj |
# | significance of Lakota                      | Battle of Wounded Knee involved nearly three hundred people shot and killed by soldiers . The massacre was part of the massacre, part <span class="searchmatch">of the United States Army .                                                             | https://tinyurl.com/cceuzwd  |
# | applications of Lakota                      | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ), also referred to as Lakhota, Teton or Teton Sioux, is a Siouan language .                                                                                                                                           | https://tinyurl.com/2n63xvh6 |
# | physical significance of Lakota             | Indigenous Elders declared that war was the result of war in North America and internationally . Lakota Elders responded to the threat of war and declared that it was not war .                                                                        | https://tinyurl.com/hl6bua6  |
# | geometry used in Lakota                     | He is a member of the Lakota Lakota People's Law Project and a co-founder of the Native American news website Last Real Indians .                                                                                                                       | https://tinyurl.com/yupsqtwn |
# | typical characteristics of Lakota           | SOO; Dakota/ <span class="searchmatch">Lakota are groups of Native American tribes and First Nations peoples from the Great Plains of North America .                                                                                                   | https://tinyurl.com/ya6aqvy3 |
# | with and without Lakota                     | The Lakota are a Native American people . Also known as the Teton Sioux (from Thítȟuŋwaŋ), they are one of the largest tribes in the world .                                                                                                            | https://tinyurl.com/sryvcns  |
# | what does Lakota represent?                 | The Lakota are a Native American people . Also known as the Teton Sioux (from Thítȟuŋwaŋ), they are one of the largest tribes in the world .                                                                                                            | https://tinyurl.com/sryvcns  |
# | what is the concept of Lakota?              | Lakota tradition has no formal leadership and displays much internal variation . Lakota religion is central to <span class="searchmatch">of the North American Plains .                                                                                 | https://tinyurl.com/ykly49ax |
# | taxonomy of Lakota                          | Apobaetis <span class="searchmatch">lakota is a species of small minnow mayfly in the family Baetidae . It is found in North America .                                                                                                                  | https://tinyurl.com/ylqzjgaj |
# | table of Lakota                             | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ), also referred to as Lakhota, Teton or Teton Sioux, is a Siouan language .                                                                                                                                           | https://tinyurl.com/2n63xvh6 |
# | list of LakotaLakota and peopleLakota table | County is named after the Oglala <span class="searchmatch">Lakota, a band of the Lakota people . Many of the county's inhabitants are members of this sub-tribe .                                                                                       | https://tinyurl.com/yk7qb8oy |
# | the analog of Lakota                        | Directors of Prairie Public are from Winnipeg . Manitoban also chairs the television programming advisory board . Since KGFE's analog service went, the service has been available in Manitoba .                                                        | https://tinyurl.com/yrjspcms |
# | physical meaning of Lakota                  | Lakota spirituality is the traditional Native American religion of the Lakota people . It is practiced primarily in the <span class="searchmatch">Lakota  reservations .                                                                                | https://tinyurl.com/ykly49ax |
# | Lakota symbolism                            | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ) is a Siouan language spoken by the Sioux people . Lakota is also known as Lakhota, Teton or Teton Sioux .                                                                                                            | https://tinyurl.com/2n63xvh6 |
# | symbolism of Lakota                         | Lakota (Lakȟótiyapi [laˈkˣɔtɪjapɪ), also referred to as Lakhota, Teton or Teton Sioux, is a Siouan language .                                                                                                                                           | https://tinyurl.com/2n63xvh6 |
# | iconographic meaning of Lakota              | Another myth mentions that the bottom half <span class="searchmatch">of </span> Orion, the Constellation <span> of the Hand, represented the arm of a chief that was ripped . is its tail .                                                             | https://tinyurl.com/yyf224af |
# | why is Lakota important?                    | The Sioux or Oceti Sakowin (/suː/ SOO; Dakota/) are groups of Native American tribes and First Nations peoples . They are known as Lakota or Očhéthi Šakówiŋ .                                                                                          | https://tinyurl.com/ya6aqvy3 |
# | generic model of a Lakota                   | The school is within two hours of the Cheyenne River Indian Reservation, the Lower Lakota Reservation . independent of the diocese . It is within 2 hours of three reservations within the Diocese of Lakota .                                          | https://tinyurl.com/ykfw3ba6 |
# | generic model representation of Lakota      | is the <span class="searchmatch">Lakota term for non-Indian white person, but it also means &quot;the one who takes the best meat for himself . Clarke, Donald. is the author of "All kinds of things"                                                  | https://tinyurl.com/9srcblt  |
# | schematic representation of Lakota          | Buffalo County, South Dakota, is home <span class="searchmatch">of the Crow Creek Indian Reservation, and Oglala <span>Lakota</span> County . Buffalo County is home to the Pine Ridge and Crow Creek Reservation .                                     | https://tinyurl.com/hnl32fz  |
# | Lakota is related to?                       | Lakȟótiyapi is the westernmost of three closely <span class="searchmatch">related languages that belong to the Siouan language family . Dakota people speak Lak  Lakota language, westernmost among the three closely related languages in the family . | https://tinyurl.com/sryvcns  |
# | Lakota conversions                          | Lakota spirituality is the traditional Native American religion of the <span class="searchmatch">Lakota</span> people . It is practiced primarily in Lakota reservations .                                                                              | https://tinyurl.com/ykly49ax |

# %%
# Summaries can easily be changed
